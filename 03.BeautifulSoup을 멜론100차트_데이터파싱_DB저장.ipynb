# %% [markdown]
# ### BeautifulSoup
# * select() 함수 사용
# * melon 100 chart 데이터 파싱

# %%
import re
import requests
from bs4 import BeautifulSoup

url = 'https://www.melon.com/chart/index.htm'
headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}
res = requests.get(url,headers=headers)
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')
    print(len(soup.select('div#tb_list tr div.wrap_song_info a[href*=playSong]')))
    print(len(soup.select("a[href*='playSong']")))
    song_list = soup.select("a[href*='playSong']")

    song_detail_lists = []  # [{},{},{}]
    for idx,tag in enumerate(song_list,1):
        song_dict = {}
        song_title = tag.text
        song_dict['title'] = song_title
        
        link = tag['href']
        matched = re.search(r"(\d+)\);", link)
        song_id = matched.group(1)
        song_dict['id'] = song_id
        
        song_url = f'https://www.melon.com/song/detail.htm?songId={song_id}'
        song_dict['url'] = song_url
        
        song_detail_lists.append(song_dict)
        print(idx, song_dict)

    song_detail_lists
# Out:
# 100
# 100
# 1 {'title': '사건의 지평선', 'id': '34819473', 'url': 'https://www.melon.com/song/detail.htm?songId=34819473'}
# 2 {'title': 'Nxde', 'id': '35730562', 'url': 'https://www.melon.com/song/detail.htm?songId=35730562'}
# 3 {'title': 'ANTIFRAGILE', 'id': '35729104', 'url': 'https://www.melon.com/song/detail.htm?songId=35729104'}
# 4 {'title': 'After LIKE', 'id': '35546497', 'url': 'https://www.melon.com/song/detail.htm?songId=35546497'}
# 5 {'title': 'Hype boy', 'id': '35454426', 'url': 'https://www.melon.com/song/detail.htm?songId=35454426'}
# 6 {'title': '새삥 (Prod. ZICO) (Feat. 호미들)', 'id': '35595136', 'url': 'https://www.melon.com/song/detail.htm?songId=35595136'}
# 7 {'title': 'Rush Hour (Feat. j-hope of BTS)', 'id': '35665282', 'url': 'https://www.melon.com/song/detail.htm?songId=35665282'}
# 8 {'title': 'Attention', 'id': '35454425', 'url': 'https://www.melon.com/song/detail.htm?songId=35454425'}
# 9 {'title': 'Monologue', 'id': '35643794', 'url': 'https://www.melon.com/song/detail.htm?songId=35643794'}
# 10 {'title': 'LOVE DIVE', 'id': '34847378', 'url': 'https://www.melon.com/song/detail.htm?songId=34847378'}
# 11 {'title': 'Shut Down', 'id': '35640077', 'url': 'https://www.melon.com/song/detail.htm?songId=35640077'}
# 12 {'title': '사랑은 늘 도망가', 'id': '34061322', 'url': 'https://www.melon.com/song/detail.htm?songId=34061322'}
# 13 {'title': '자격지심 (Feat. ZICO)', 'id': '35685439', 'url': 'https://www.melon.com/song/detail.htm?songId=35685439'}
# 14 {'title': 'Pink Venom', 'id': '35542908', 'url': 'https://www.melon.com/song/detail.htm?songId=35542908'}
# 15 {'title': '우리들의 블루스', 'id': '34908740', 'url': 'https://www.melon.com/song/detail.htm?songId=34908740'}
# 16 {'title': '딱 10CM만', 'id': '35668899', 'url': 'https://www.melon.com/song/detail.htm?songId=35668899'}
# 17 {'title': '다시 만날 수 있을까', 'id': '35008524', 'url': 'https://www.melon.com/song/detail.htm?songId=35008524'}
# 18 {'title': 'TOMBOY', 'id': '34754292', 'url': 'https://www.melon.com/song/detail.htm?songId=34754292'}
# 19 {'title': '그때 그 순간 그대로 (그그그)', 'id': '35383397', 'url': 'https://www.melon.com/song/detail.htm?songId=35383397'}
# 20 {'title': '해요 (2022)', 'id': '35252996', 'url': 'https://www.melon.com/song/detail.htm?songId=35252996'}
# 21 {'title': '우린 그렇게 사랑해서', 'id': '35669445', 'url': 'https://www.melon.com/song/detail.htm?songId=35669445'}
# 22 {'title': '그라데이션', 'id': '35361345', 'url': 'https://www.melon.com/song/detail.htm?songId=35361345'}
# 23 {'title': '무지개', 'id': '35008525', 'url': 'https://www.melon.com/song/detail.htm?songId=35008525'}
# 24 {'title': '이제 나만 믿어요', 'id': '32508053', 'url': 'https://www.melon.com/song/detail.htm?songId=32508053'}
# 25 {'title': 'Cookie', 'id': '35485544', 'url': 'https://www.melon.com/song/detail.htm?songId=35485544'}
# 26 {'title': '사랑인가 봐', 'id': '34657844', 'url': 'https://www.melon.com/song/detail.htm?songId=34657844'}
# 27 {'title': '아버지', 'id': '35008527', 'url': 'https://www.melon.com/song/detail.htm?songId=35008527'}
# 28 {'title': '내가 아니라도', 'id': '34787226', 'url': 'https://www.melon.com/song/detail.htm?songId=34787226'}
# 29 {'title': 'A bientot', 'id': '35008528', 'url': 'https://www.melon.com/song/detail.htm?songId=35008528'}
# 30 {'title': '정이라고 하자 (Feat. 10CM)', 'id': '34927767', 'url': 'https://www.melon.com/song/detail.htm?songId=34927767'}
# 31 {'title': '나의 X에게', 'id': '34943312', 'url': 'https://www.melon.com/song/detail.htm?songId=34943312'}
# 32 {'title': '보고싶었어', 'id': '35383398', 'url': 'https://www.melon.com/song/detail.htm?songId=35383398'}
# 33 {'title': 'ELEVEN', 'id': '34349913', 'url': 'https://www.melon.com/song/detail.htm?songId=34349913'}
# 34 {'title': '손이 참 곱던 그대', 'id': '35008526', 'url': 'https://www.melon.com/song/detail.htm?songId=35008526'}
# 35 {'title': '인생찬가', 'id': '35008534', 'url': 'https://www.melon.com/song/detail.htm?songId=35008534'}
# 36 {'title': 'That That (prod. & feat. SUGA of BTS)', 'id': '34997078', 'url': 'https://www.melon.com/song/detail.htm?songId=34997078'}
# 37 {'title': '너의 모든 순간', 'id': '4446485', 'url': 'https://www.melon.com/song/detail.htm?songId=4446485'}
# 38 {'title': 'FEARLESS', 'id': '35009233', 'url': 'https://www.melon.com/song/detail.htm?songId=35009233'}
# 39 {'title': '사랑해 진짜', 'id': '35008531', 'url': 'https://www.melon.com/song/detail.htm?songId=35008531'}
# 40 {'title': '연애편지', 'id': '35008532', 'url': 'https://www.melon.com/song/detail.htm?songId=35008532'}
# 41 {'title': '떠나보낼 준비해 둘걸 그랬어', 'id': '35730698', 'url': 'https://www.melon.com/song/detail.htm?songId=35730698'}
# 42 {'title': '취중고백', 'id': '34431086', 'url': 'https://www.melon.com/song/detail.htm?songId=34431086'}
# 43 {'title': "That's Hilarious", 'id': '34864406', 'url': 'https://www.melon.com/song/detail.htm?songId=34864406'}
# 44 {'title': '사랑역', 'id': '35008529', 'url': 'https://www.melon.com/song/detail.htm?songId=35008529'}
# 45 {'title': '보금자리', 'id': '35008530', 'url': 'https://www.melon.com/song/detail.htm?songId=35008530'}
# 46 {'title': '사랑해요 그대를', 'id': '35008533', 'url': 'https://www.melon.com/song/detail.htm?songId=35008533'}
# 47 {'title': 'FOREVER 1', 'id': '35504734', 'url': 'https://www.melon.com/song/detail.htm?songId=35504734'}
# 48 {'title': '내 기쁨은 너가 벤틀리를 끄는 거야', 'id': '34100776', 'url': 'https://www.melon.com/song/detail.htm?songId=34100776'}
# 49 {'title': '다정히 내 이름을 부르면', 'id': '33496587', 'url': 'https://www.melon.com/song/detail.htm?songId=33496587'}
# 50 {'title': '주저하는 연인들을 위해', 'id': '31666417', 'url': 'https://www.melon.com/song/detail.htm?songId=31666417'}
# 51 {'title': 'LOVE me', 'id': '34875621', 'url': 'https://www.melon.com/song/detail.htm?songId=34875621'}
# 52 {'title': "I Don't Think That I Like Her", 'id': '35640751', 'url': 'https://www.melon.com/song/detail.htm?songId=35640751'}
# 53 {'title': 'Dynamite', 'id': '32872978', 'url': 'https://www.melon.com/song/detail.htm?songId=32872978'}
# 54 {'title': '새벽에 걸려온 너의 전화는', 'id': '35484543', 'url': 'https://www.melon.com/song/detail.htm?songId=35484543'}
# 55 {'title': 'SNEAKERS', 'id': '35413033', 'url': 'https://www.melon.com/song/detail.htm?songId=35413033'}
# 56 {'title': 'Love story', 'id': '34930368', 'url': 'https://www.melon.com/song/detail.htm?songId=34930368'}
# 57 {'title': 'LAW (Prod. Czaer)', 'id': '35595137', 'url': 'https://www.melon.com/song/detail.htm?songId=35595137'}
# 58 {'title': '첫사랑', 'id': '31343875', 'url': 'https://www.melon.com/song/detail.htm?songId=31343875'}
# 59 {'title': 'Left and Right (Feat. Jung Kook of BTS)', 'id': '35331586', 'url': 'https://www.melon.com/song/detail.htm?songId=35331586'}
# 60 {'title': '모든 날, 모든 순간 (Every day, Every Moment)', 'id': '30962526', 'url': 'https://www.melon.com/song/detail.htm?songId=30962526'}
# 61 {'title': '고백연습', 'id': '35779712', 'url': 'https://www.melon.com/song/detail.htm?songId=35779712'}
# 62 {'title': '도깨비불 (Illusion)', 'id': '35238221', 'url': 'https://www.melon.com/song/detail.htm?songId=35238221'}
# 63 {'title': '밤하늘의 별을(2020)', 'id': '33061995', 'url': 'https://www.melon.com/song/detail.htm?songId=33061995'}
# 64 {'title': 'STAY', 'id': '33658563', 'url': 'https://www.melon.com/song/detail.htm?songId=33658563'}
# 65 {'title': '봄여름가을겨울 (Still Life)', 'id': '34845949', 'url': 'https://www.melon.com/song/detail.htm?songId=34845949'}
# 66 {'title': 'Butter', 'id': '33507137', 'url': 'https://www.melon.com/song/detail.htm?songId=33507137'}
# 67 {'title': 'POP!', 'id': '35333345', 'url': 'https://www.melon.com/song/detail.htm?songId=35333345'}
# 68 {'title': '스티커 사진', 'id': '35391594', 'url': 'https://www.melon.com/song/detail.htm?songId=35391594'}
# 69 {'title': '사랑한다고 말해줘', 'id': '35505810', 'url': 'https://www.melon.com/song/detail.htm?songId=35505810'}
# 70 {'title': 'The Astronaut', 'id': '35779025', 'url': 'https://www.melon.com/song/detail.htm?songId=35779025'}
# 71 {'title': '신호등', 'id': '33480898', 'url': 'https://www.melon.com/song/detail.htm?songId=33480898'}
# 72 {'title': '봄날', 'id': '30244931', 'url': 'https://www.melon.com/song/detail.htm?songId=30244931'}
# 73 {'title': 'Yet To Come', 'id': '35272060', 'url': 'https://www.melon.com/song/detail.htm?songId=35272060'}
# 74 {'title': '그래서 그대는', 'id': '35709043', 'url': 'https://www.melon.com/song/detail.htm?songId=35709043'}
# 75 {'title': 'Permission to Dance', 'id': '33666269', 'url': 'https://www.melon.com/song/detail.htm?songId=33666269'}
# 76 {'title': 'Feel My Rhythm', 'id': '34772475', 'url': 'https://www.melon.com/song/detail.htm?songId=34772475'}
# 77 {'title': '통화연결음', 'id': '35526685', 'url': 'https://www.melon.com/song/detail.htm?songId=35526685'}
# 78 {'title': 'MY BAG', 'id': '34754299', 'url': 'https://www.melon.com/song/detail.htm?songId=34754299'}
# 79 {'title': 'strawberry moon', 'id': '34101563', 'url': 'https://www.melon.com/song/detail.htm?songId=34101563'}
# 80 {'title': '못해', 'id': '35694868', 'url': 'https://www.melon.com/song/detail.htm?songId=35694868'}
# 81 {'title': '내 손을 잡아', 'id': '3414749', 'url': 'https://www.melon.com/song/detail.htm?songId=3414749'}
# 82 {'title': '드라마', 'id': '34481680', 'url': 'https://www.melon.com/song/detail.htm?songId=34481680'}
# 83 {'title': 'INVU', 'id': '34626109', 'url': 'https://www.melon.com/song/detail.htm?songId=34626109'}
# 84 {'title': '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)', 'id': '34256568', 'url': 'https://www.melon.com/song/detail.htm?songId=34256568'}
# 85 {'title': 'Off My Face', 'id': '33359309', 'url': 'https://www.melon.com/song/detail.htm?songId=33359309'}
# 86 {'title': "바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)", 'id': '35388184', 'url': 'https://www.melon.com/song/detail.htm?songId=35388184'}
# 87 {'title': '그중에 그대를 만나', 'id': '35667692', 'url': 'https://www.melon.com/song/detail.htm?songId=35667692'}
# 88 {'title': '늦은 밤 헤어지긴 너무 아쉬워', 'id': '35177030', 'url': 'https://www.melon.com/song/detail.htm?songId=35177030'}
# 89 {'title': 'DICE', 'id': '35643842', 'url': 'https://www.melon.com/song/detail.htm?songId=35643842'}
# 90 {'title': 'Next Level', 'id': '33487342', 'url': 'https://www.melon.com/song/detail.htm?songId=33487342'}
# 91 {'title': 'Girls', 'id': '35238220', 'url': 'https://www.melon.com/song/detail.htm?songId=35238220'}
# 92 {'title': '나의 목소리로', 'id': '35690912', 'url': 'https://www.melon.com/song/detail.htm?songId=35690912'}
# 93 {'title': '너를 생각해', 'id': '33978183', 'url': 'https://www.melon.com/song/detail.htm?songId=33978183'}
# 94 {'title': 'GANADARA (Feat. 아이유)', 'id': '34752700', 'url': 'https://www.melon.com/song/detail.htm?songId=34752700'}
# 95 {'title': "I Ain't Worried", 'id': '35215215', 'url': 'https://www.melon.com/song/detail.htm?songId=35215215'}
# 96 {'title': 'Talk that Talk', 'id': '35560680', 'url': 'https://www.melon.com/song/detail.htm?songId=35560680'}
# 97 {'title': '인생은 뷰티풀', 'id': '35609035', 'url': 'https://www.melon.com/song/detail.htm?songId=35609035'}
# 98 {'title': 'GHOST TOWN', 'id': '34098217', 'url': 'https://www.melon.com/song/detail.htm?songId=34098217'}
# 99 {'title': 'Weekend', 'id': '33655994', 'url': 'https://www.melon.com/song/detail.htm?songId=33655994'}
# 100 {'title': '듣고 싶을까', 'id': '34701627', 'url': 'https://www.melon.com/song/detail.htm?songId=34701627'}

# %%
import re
song_lyric_lists = []
song_lyric_dict = {}
for song in song_detail_lists:
    html = requests.get(song['url'], headers=headers).text
    soup = BeautifulSoup(html,'html.parser')
    song_lyric_dict['곡명'] = song['title']
    song_lyric_dict['가수'] = soup.select('a[href*=".goArtistDetail"] span')[0].text
    song_lyric_dict['발매일'] = soup.select('div.meta dd')[1].text
    song_lyric_dict['장르'] = soup.select('div.meta dd')[2].text
    print(song['url'])
#    print(soup.select('div#d_video_summary')[0].text)
    if(soup.select('div#d_video_summary')):
        lyric = soup.select('div#d_video_summary')[0].text
    else:
        lyric = ''
    regex = re.compile(r'[\n\r\t]')
    song_lyric_dict['가사'] = regex.sub('', lyric.strip())
    song_lyric_lists.append(song_lyric_dict)
    song_lyric_dict = {}

print(len(song_lyric_lists))    
#song_lyric_lists
# Out:
# https://www.melon.com/song/detail.htm?songId=32578498
# https://www.melon.com/song/detail.htm?songId=32646938
# https://www.melon.com/song/detail.htm?songId=32614125
# https://www.melon.com/song/detail.htm?songId=32636656
# https://www.melon.com/song/detail.htm?songId=32491274
# https://www.melon.com/song/detail.htm?songId=32620700
# https://www.melon.com/song/detail.htm?songId=32559781
# https://www.melon.com/song/detail.htm?songId=32399830
# https://www.melon.com/song/detail.htm?songId=32583036
# https://www.melon.com/song/detail.htm?songId=32631950
# https://www.melon.com/song/detail.htm?songId=32473998
# https://www.melon.com/song/detail.htm?songId=31737197
# https://www.melon.com/song/detail.htm?songId=32508146
# https://www.melon.com/song/detail.htm?songId=32399832
# https://www.melon.com/song/detail.htm?songId=32559782
# https://www.melon.com/song/detail.htm?songId=32620702
# https://www.melon.com/song/detail.htm?songId=32508053
# https://www.melon.com/song/detail.htm?songId=32298623
# https://www.melon.com/song/detail.htm?songId=32620706
# https://www.melon.com/song/detail.htm?songId=32345931
# https://www.melon.com/song/detail.htm?songId=32486613
# https://www.melon.com/song/detail.htm?songId=32323969
# https://www.melon.com/song/detail.htm?songId=32521396
# https://www.melon.com/song/detail.htm?songId=32399834
# https://www.melon.com/song/detail.htm?songId=31979846
# https://www.melon.com/song/detail.htm?songId=32650659
# https://www.melon.com/song/detail.htm?songId=32620704
# https://www.melon.com/song/detail.htm?songId=32399827
# https://www.melon.com/song/detail.htm?songId=32003395
# https://www.melon.com/song/detail.htm?songId=32620703
# https://www.melon.com/song/detail.htm?songId=32438894
# https://www.melon.com/song/detail.htm?songId=32528369
# https://www.melon.com/song/detail.htm?songId=32651098
# https://www.melon.com/song/detail.htm?songId=32399835
# https://www.melon.com/song/detail.htm?songId=32055419
# https://www.melon.com/song/detail.htm?songId=32183386
# https://www.melon.com/song/detail.htm?songId=32313543
# https://www.melon.com/song/detail.htm?songId=32399828
# https://www.melon.com/song/detail.htm?songId=32620701
# https://www.melon.com/song/detail.htm?songId=32399833
# https://www.melon.com/song/detail.htm?songId=32399837
# https://www.melon.com/song/detail.htm?songId=32620705
# https://www.melon.com/song/detail.htm?songId=32561690
# https://www.melon.com/song/detail.htm?songId=32224272
# https://www.melon.com/song/detail.htm?songId=32399829
# https://www.melon.com/song/detail.htm?songId=32399831
# https://www.melon.com/song/detail.htm?songId=32399826
# https://www.melon.com/song/detail.htm?songId=32137576
# https://www.melon.com/song/detail.htm?songId=32421335
# https://www.melon.com/song/detail.htm?songId=32399838
# https://www.melon.com/song/detail.htm?songId=32399836
# https://www.melon.com/song/detail.htm?songId=32616054
# https://www.melon.com/song/detail.htm?songId=32397381
# https://www.melon.com/song/detail.htm?songId=30764790
# https://www.melon.com/song/detail.htm?songId=32217921
# https://www.melon.com/song/detail.htm?songId=32378104
# https://www.melon.com/song/detail.htm?songId=32323330
# https://www.melon.com/song/detail.htm?songId=32653982
# https://www.melon.com/song/detail.htm?songId=32361098
# https://www.melon.com/song/detail.htm?songId=32572926
# https://www.melon.com/song/detail.htm?songId=32156286
# https://www.melon.com/song/detail.htm?songId=32377231
# https://www.melon.com/song/detail.htm?songId=31029291
# https://www.melon.com/song/detail.htm?songId=32590490
# https://www.melon.com/song/detail.htm?songId=32273582
# https://www.melon.com/song/detail.htm?songId=31853557
# https://www.melon.com/song/detail.htm?songId=32495729
# https://www.melon.com/song/detail.htm?songId=32441451
# https://www.melon.com/song/detail.htm?songId=32596760
# https://www.melon.com/song/detail.htm?songId=32445339
# https://www.melon.com/song/detail.htm?songId=32560653
# https://www.melon.com/song/detail.htm?songId=32224409
# https://www.melon.com/song/detail.htm?songId=32061975
# https://www.melon.com/song/detail.htm?songId=32633203
# https://www.melon.com/song/detail.htm?songId=32624988
# https://www.melon.com/song/detail.htm?songId=32381408
# https://www.melon.com/song/detail.htm?songId=32588768
# https://www.melon.com/song/detail.htm?songId=32636587
# https://www.melon.com/song/detail.htm?songId=32603264
# https://www.melon.com/song/detail.htm?songId=32550314
# https://www.melon.com/song/detail.htm?songId=30962526
# https://www.melon.com/song/detail.htm?songId=30244931
# https://www.melon.com/song/detail.htm?songId=32457751
# https://www.melon.com/song/detail.htm?songId=32393669
# https://www.melon.com/song/detail.htm?songId=32122539
# https://www.melon.com/song/detail.htm?songId=32556676
# https://www.melon.com/song/detail.htm?songId=32455023
# https://www.melon.com/song/detail.htm?songId=32555799
# https://www.melon.com/song/detail.htm?songId=32187544
# https://www.melon.com/song/detail.htm?songId=32594046
# https://www.melon.com/song/detail.htm?songId=32362652
# https://www.melon.com/song/detail.htm?songId=31368699
# https://www.melon.com/song/detail.htm?songId=32457760
# https://www.melon.com/song/detail.htm?songId=32457753
# https://www.melon.com/song/detail.htm?songId=32143487
# https://www.melon.com/song/detail.htm?songId=32555791
# https://www.melon.com/song/detail.htm?songId=32584913
# https://www.melon.com/song/detail.htm?songId=32175937
# https://www.melon.com/song/detail.htm?songId=32651694
# https://www.melon.com/song/detail.htm?songId=32653574
# 100

# %%
import pandas as pd

print(len(song_lyric_lists))

#컬럼명을 설정하여 DataFrame 객체를 저장한다.
data_df = pd.DataFrame(columns=['곡명', '가수', '발매일','장르', '가사'])

for data in song_lyric_lists:
    series_obj = pd.Series(data)
    data_df = data_df.append(series_obj,ignore_index = True)

data_df.head(2)
# Out:
# 100
#                             곡명           가수         발매일    장르  \
# 0  에잇(Prod.&Feat. SUGA of BTS)          아이유  2020.05.06  록/메탈
# 1             깡 Official Remix  식케이 (Sik-K)  2020.06.04  랩/힙합
#
#                                                   가사
# 0  So are you happy nowFinally happy now are you뭐...
# 1  Yeah yeah H1GHR GGANG back at it againYeah yea...

# %%
print(data_df.shape)
# Out:
# (100, 5)

# %%
data_df.loc[data_df['가수'] == '태연 (TAEYEON)',:]
# Out:
#        곡명            가수         발매일         장르  \
# 59  Happy  태연 (TAEYEON)  2020.05.04  R&B;/Soul
#
#                                                    가사
# 59  Happy La La LaHappy La La LaHappy La La LaHapp...

# %%
data_df['가수'].unique()
# Out:
# array(['아이유', '식케이 (Sik-K)', '전미도', 'TWICE (트와이스)', '조정석',
#        '백현 (BAEKHYUN)', '오마이걸', '방탄소년단', '볼빨간사춘기', '미도와 파라솔', '조이 (JOY)',
#        '규현 (KYUHYUN)', '임영웅', '가호 (Gaho)', '엠씨더맥스 (M.C the MAX)', '어반자카파',
#        'Tones And I', '런치', '장범준', '오반', 'Apink (에이핑크)', '전상근',
#        'Maroon 5', '지코 (ZICO)', '휘인 (Whee In)', '창모 (CHANGMO)',
#        'Dua Lipa', '황인욱', '비', 'EXO', '서은광 (비투비)', '하현우 (국카스텐)',
#        '태연 (TAEYEON)', '노을', '김필', 'Anne-Marie', 'Raiden',
#        'Red Velvet (레드벨벳)', '마크툽 (MAKTUB)', '수호 (SUHO)', 'ITZY (있지)',
#        '김호중', '진민호', 'AKMU (악동뮤지션)', 'IZ*ONE (아이즈원)', 'NCT 127', '이예준',
#        '투모로우바이투게더', '폴킴', '영탁', 'Conan Gray', '권진아', '신예영',
#        'Ariana Grande', '마마무 (Mamamoo)', '장민호', '하성운'], dtype=object)

# %%
data_df['장르'].value_counts()
# Out:
# 랩/힙합               21
# 성인가요               15
# 발라드, 국내드라마         13
# 댄스                 12
# R&B;/Soul          10
# 발라드                 9
# POP                 6
# 록/메탈, 국내드라마         4
# 록/메탈                4
# R&B;/Soul, 인디음악     2
# 인디음악, 포크/블루스        2
# 랩/힙합, 인디음악          2
# Name: 장르, dtype: int64

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://python:" + "1111!" + "@localhost/python_db", encoding='utf-8')
conn = engine.connect()

data_df.to_sql(name="songs",con=engine,if_exists='replace',index=False)

# %%
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://python:" + "1111!" + "@localhost/python_db", encoding='utf-8')
conn = engine.connect()
print(engine,conn)
df = pd.read_sql_table('songs', conn)
#print(df.head())


sql = "SELECT 곡명,가수,장르 FROM songs order by 가수 asc "
df2 = pd.read_sql(sql, conn)
print(df2.head(20))

conn.close()
# Out:
# Engine(mysql+mysqldb://python:***@localhost/python_db) <sqlalchemy.engine.base.Connection object at 0x000001E3CB472668>
#                            곡명                 가수           장르
# 0   어떻게 이별까지 사랑하겠어, 널 사랑하는 거지       AKMU (악동뮤지션)          발라드
# 1                        2002         Anne-Marie          POP
# 2              덤더럼(Dumhdurum)       Apink (에이핑크)           댄스
# 3                Stuck with U      Ariana Grande          POP
# 4                      Maniac         Conan Gray          POP
# 5             Don't Start Now           Dua Lipa          POP
# 6                   Obsession                EXO           댄스
# 7                     WANNABE          ITZY (있지)           댄스
# 8                      FIESTA      IZ*ONE (아이즈원)           댄스
# 9                    Memories           Maroon 5          POP
# 10                      Punch            NCT 127         랩/힙합
# 11           영웅 (英雄; Kick It)            NCT 127         랩/힙합
# 12      Yours (Feat. 이하이, 창모)             Raiden    R&B;/Soul
# 13                     Psycho  Red Velvet (레드벨벳)           댄스
# 14               Dance Monkey        Tones And I          POP
# 15                MORE & MORE       TWICE (트와이스)           댄스
# 16                         시작          가호 (Gaho)  록/메탈, 국내드라마
# 17               Lonely Night                권진아   발라드, 국내드라마
# 18                 화려하지 않은 고백       규현 (KYUHYUN)   발라드, 국내드라마
# 19                    그때 그 아인                 김필   발라드, 국내드라마
